# %% [markdown]
# ## Attempting to replicate the results from:
# # **CheXpert: A large chest radiograph dataset with uncertainty labels and expert comparison**
# ## https://arxiv.org/abs/1901.07031
# ##### Irvin, Jeremy and Rajpurkar, Pranav and Ko, Michael and Yu, Yifan and Ciurea-Ilcus, Silviana and Chute, Chris and Marklund, Henrik and Haghgoo, Behzad and Ball, Robyn and Shpanskaya, Katie and others

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from torchvision.models import *
import yaml
import pandas as pd
import datetime

from sklearn.metrics import roc_auc_score

# %% [markdown]
# ### Load configuration with local path and url for dataset

# %%
with open("config.yml", 'r') as ymlfile:
    cfg = yaml.load(ymlfile)
    path = cfg['path']
# Out:
# /home/trevor/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
chestxrays_root = Path(path)
data_path = chestxrays_root

# %%
data_path
# Out:
# PosixPath('/media/trevor/main-storag')

# %% [markdown]
# ### Load Data

# %%
full_train_df = pd.read_csv('/media/trevor/main-storag/CheXpert-v1.0-small/train.csv')
full_valid_df = pd.read_csv('/media/trevor/main-storag/CheXpert-v1.0-small/valid.csv')

# %%
chexnet_targets = ['No Finding',
       'Enlarged Cardiomediastinum', 'Cardiomegaly', 'Lung Opacity',
       'Lung Lesion', 'Edema', 'Consolidation', 'Pneumonia', 'Atelectasis',
       'Pneumothorax', 'Pleural Effusion', 'Pleural Other', 'Fracture',
       'Support Devices']

chexpert_targets = ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema', 'Pleural Effusion']

# %% [markdown]
# ### Uncertainty Approaches
#
# The CheXpert paper outlines several different approaches to mapping using the uncertainty labels in the data:
#
# - Ignoring - essentially removing from the calculation in the loss function
# - Binary mapping - sending uncertain values to either 0 or 1
# - Prevalence mapping - use the rate of prevelance of the feature as it's target value
# - Self-training - consider the uncertain values as unlabeled
# - 3-Class Classification - retain a separate value for uncertain and try to predict it as a class in its own right
#
#
# The paper gives the results of different experiments with the above approaches and indicates the most accurate approach for each feature.
#
# |Approach/Feature|Atelectasis|Cardiomegaly|Consolidation|Edema|PleuralEffusion|
# |-----------|-----------|-----------|-----------|-----------|-----------|
# |`U-Ignore`|0.818(0.759,0.877)|0.828(0.769,0.888)|0.938(0.905,0.970)|0.934(0.893,0.975)|0.928(0.894,0.962)|
# |`U-Zeros`|0.811(0.751,0.872)|0.840(0.783,0.897)|0.932(0.898,0.966)|0.929(0.888,0.970)|0.931(0.897,0.965)|
# |`U-Ones`|**0.858(0.806,0.910)**|0.832(0.773,0.890)|0.899(0.854,0.944)|**0.941(0.903,0.980)**|0.934(0.901,0.967)|
# |`U-Mean`|0.821(0.762,0.879)|0.832(0.771,0.892)|0.937(0.905,0.969)|0.939(0.902,0.975)|0.930(0.896,0.965)|
# |`U-SelfTrained`|0.833(0.776,0.890)|0.831(0.770,0.891)|**0.939(0.908,0.971)**|0.935(0.896,0.974)|0.932(0.899,0.966)|
# |`U-MultiClass`|0.821(0.763,0.879)|**0.854(0.800,0.909)**|0.937(0.905,0.969)|0.928(0.887,0.968)|**0.936(0.904,0.967)**|
#
# The binary mapping approaches (U-Ones and U-Zeros) are easiest to implement and so to begin with we take the best option between U-Ones and U-Zeros for each feature
#
# - Atelectasis `U-Ones`
# - Cardiomegaly `U-Zeros`
# - Consolidation `U-Zeros`
# - Edema `U-Ones`
# - Pleural Effusion `U-Zeros`

# %%
u_targets = []
p_targets = ['Atelectasis_p', 'Cardiomegaly_p', 'Consolidation_p', 'Edema_p', 'Pleural Effusion_p']
n_targets = ['Atelectasis_n', 'Cardiomegaly_n', 'Consolidation_n', 'Edema_n', 'Pleural Effusion_n']
u_multi_targets = u_targets + p_targets + n_targets

# %% [markdown]
# ### Add target features string

# %%
# Determine the labels of the sample
def feature_string(row):
    feature_list = []
    for feature in chexpert_targets:
        # if 1 then has the feature
        if row[feature] == 1:
            feature_list.append(feature+'_p')
        elif row[feature] == 0:
            feature_list.append(feature+'_n')
            
    return ';'.join(feature_list)

# %%
full_train_df['train_valid'] = False
full_valid_df['train_valid'] = True

# %% [markdown]
# ##### Create patient and study columns

# %%
full_train_df['patient'] = full_train_df.Path.str.split('/',3,True)[2]
full_train_df  ['study'] = full_train_df.Path.str.split('/',4,True)[3]

full_valid_df['patient'] = full_valid_df.Path.str.split('/',3,True)[2]
full_valid_df  ['study'] = full_valid_df.Path.str.split('/',4,True)[3]

# %%
full_df = pd.concat([full_train_df, full_valid_df])
full_df = full_df.reset_index(drop=True)

# %%
full_df['feature_string'] = full_df.apply(feature_string,axis = 1).fillna('')
full_df
# Out:
#                                                      Path     Sex  Age  \
# 0       CheXpert-v1.0-small/train/patient00001/study1/...  Female   68
# 1       CheXpert-v1.0-small/train/patient00002/study2/...  Female   87
# 2       CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 3       CheXpert-v1.0-small/train/patient00003/study1/...    Male   41
# 4       CheXpert-v1.0-small/train/patient00004/study1/...  Female   20
# 5       CheXpert-v1.0-small/train/patient00005/study1/...    Male   33
# 6       CheXpert-v1.0-small/train/patient00005/study1/...    Male   33
# 7       CheXpert-v1.0-small/train/patient00005/study2/...    Male   33
# 8       CheXpert-v1.0-small/train/patient00006/study1/...  Female   42
# 9       CheXpert-v1.0-small/train/patient00008/study1/...    Male   81
# 10      CheXpert-v1.0-small/train/patient00008/study2/...    Male   81
# 11      CheXpert-v1.0-small/train/patient00009/study1/...    Male   76
# 12      CheXpert-v1.0-small/train/patient00009/study1/...    Male   76
# 13      CheXpert-v1.0-small/train/patient00010/study1/...  Female   50
# 14      CheXpert-v1.0-small/train/patient00010/study1/...  Female   50
# 15      CheXpert-v1.0-small/train/patient00011/study13...  Female   22
# 16      CheXpert-v1.0-small/train/patient00011/study1/...  Female   19
# 17      CheXpert-v1.0-small/train/patient00011/study7/...  Female   19
# 18      CheXpert-v1.0-small/train/patient00011/study2/...  Female   19
# 19      CheXpert-v1.0-small/train/patient00011/study10...  Female   19
# 20      CheXpert-v1.0-small/train/patient00011/study9/...  Female   19
# 21      CheXpert-v1.0-small/train/patient00011/study11...  Female   19
# 22      CheXpert-v1.0-small/train/patient00011/study8/...  Female   19
# 23      CheXpert-v1.0-small/train/patient00011/study3/...  Female   19
# 24      CheXpert-v1.0-small/train/patient00011/study6/...  Female   19
# 25      CheXpert-v1.0-small/train/patient00012/study3/...  Female   61
# 26      CheXpert-v1.0-small/train/patient00012/study3/...  Female   61
# 27      CheXpert-v1.0-small/train/patient00012/study2/...  Female   55
# 28      CheXpert-v1.0-small/train/patient00012/study2/...  Female   55
# 29      CheXpert-v1.0-small/train/patient00012/study1/...  Female   55
# ...                                                   ...     ...  ...
# 178930  CheXpert-v1.0-small/valid/patient64711/study1/...  Female   80
# 178931  CheXpert-v1.0-small/valid/patient64712/study1/...  Female   75
# 178932  CheXpert-v1.0-small/valid/patient64713/study1/...  Female   76
# 178933  CheXpert-v1.0-small/valid/patient64714/study1/...    Male   63
# 178934  CheXpert-v1.0-small/valid/patient64715/study1/...    Male   81
# 178935  CheXpert-v1.0-small/valid/patient64716/study1/...  Female   68
# 178936  CheXpert-v1.0-small/valid/patient64717/study1/...    Male   90
# 178937  CheXpert-v1.0-small/valid/patient64718/study1/...    Male   83
# 178938  CheXpert-v1.0-small/valid/patient64719/study1/...    Male   68
# 178939  CheXpert-v1.0-small/valid/patient64720/study1/...  Female   77
# 178940  CheXpert-v1.0-small/valid/patient64721/study1/...    Male   67
# 178941  CheXpert-v1.0-small/valid/patient64722/study1/...  Female   81
# 178942  CheXpert-v1.0-small/valid/patient64723/study1/...    Male   77
# 178943  CheXpert-v1.0-small/valid/patient64724/study1/...  Female   54
# 178944  CheXpert-v1.0-small/valid/patient64725/study1/...    Male   75
# 178945  CheXpert-v1.0-small/valid/patient64726/study1/...    Male   60
# 178946  CheXpert-v1.0-small/valid/patient64727/study1/...  Female   59
# 178947  CheXpert-v1.0-small/valid/patient64728/study1/...    Male   76
# 178948  CheXpert-v1.0-small/valid/patient64729/study1/...    Male   72
# 178949  CheXpert-v1.0-small/valid/patient64730/study1/...  Female   36
# 178950  CheXpert-v1.0-small/valid/patient64731/study1/...    Male   60
# 178951  CheXpert-v1.0-small/valid/patient64732/study1/...  Female   49
# 178952  CheXpert-v1.0-small/valid/patient64733/study1/...    Male   87
# 178953  CheXpert-v1.0-small/valid/patient64734/study1/...    Male   45
# 178954  CheXpert-v1.0-small/valid/patient64735/study1/...  Female   63
# 178955  CheXpert-v1.0-small/valid/patient64736/study1/...  Female   57
# 178956  CheXpert-v1.0-small/valid/patient64737/study1/...    Male   65
# 178957  CheXpert-v1.0-small/valid/patient64738/study1/...    Male   71
# 178958  CheXpert-v1.0-small/valid/patient64739/study1/...  Female   45
# 178959  CheXpert-v1.0-small/valid/patient64740/study1/...    Male   90
#
#        Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  \
# 0              Frontal    AP         1.0                         NaN
# 1              Frontal    AP         NaN                         NaN
# 2              Frontal    AP         NaN                         NaN
# 3              Frontal    AP         NaN                         NaN
# 4              Frontal    PA         1.0                         0.0
# 5              Frontal    PA         1.0                         NaN
# 6              Lateral   NaN         1.0                         NaN
# 7              Frontal    AP         NaN                         NaN
# 8              Frontal    AP         1.0                         0.0
# 9              Frontal    AP         NaN                         NaN
# 10             Frontal    AP         NaN                         NaN
# 11             Frontal    PA         NaN                         NaN
# 12             Lateral   NaN         NaN                         NaN
# 13             Frontal    PA         1.0                         0.0
# 14             Lateral   NaN         1.0                         0.0
# 15             Frontal    PA         NaN                         0.0
# 16             Frontal    AP         NaN                         NaN
# 17             Frontal    AP         NaN                         NaN
# 18             Frontal    AP         NaN                         NaN
# 19             Frontal    AP         NaN                         NaN
# 20             Frontal    AP         NaN                         1.0
# 21             Frontal    AP         NaN                         NaN
# 22             Frontal    AP         NaN                         NaN
# 23             Frontal    AP         NaN                         NaN
# 24             Frontal    AP         NaN                         NaN
# 25             Frontal    PA         NaN                         0.0
# 26             Lateral   NaN         NaN                         0.0
# 27             Frontal    PA         NaN                        -1.0
# 28             Lateral   NaN         NaN                        -1.0
# 29             Frontal    PA         NaN                         0.0
# ...                ...   ...         ...                         ...
# 178930         Frontal    AP         0.0                         1.0
# 178931         Frontal    AP         0.0                         1.0
# 178932         Frontal    AP         0.0                         0.0
# 178933         Frontal    AP         0.0                         1.0
# 178934         Frontal    AP         0.0                         0.0
# 178935         Frontal    AP         1.0                         0.0
# 178936         Frontal    AP         0.0                         1.0
# 178937         Frontal    AP         0.0                         1.0
# 178938         Frontal    AP         0.0                         1.0
# 178939         Frontal    AP         0.0                         0.0
# 178940         Frontal    AP         1.0                         0.0
# 178941         Frontal    AP         0.0                         1.0
# 178942         Frontal    AP         0.0                         1.0
# 178943         Frontal    AP         0.0                         0.0
# 178944         Frontal    AP         0.0                         0.0
# 178945         Frontal    AP         0.0                         1.0
# 178946         Frontal    AP         1.0                         0.0
# 178947         Frontal    AP         0.0                         0.0
# 178948         Frontal    AP         0.0                         1.0
# 178949         Frontal    AP         0.0                         0.0
# 178950         Frontal    AP         0.0                         0.0
# 178951         Frontal    AP         0.0                         1.0
# 178952         Frontal    AP         0.0                         1.0
# 178953         Frontal    AP         0.0                         1.0
# 178954         Frontal    AP         0.0                         0.0
# 178955         Frontal    AP         0.0                         0.0
# 178956         Frontal    AP         0.0                         0.0
# 178957         Frontal    AP         0.0                         1.0
# 178958         Frontal    AP         0.0                         1.0
# 178959         Frontal    AP         0.0                         1.0
#
#         Cardiomegaly  Lung Opacity  Lung Lesion  ...  Atelectasis  \
# 0                NaN           NaN          NaN  ...          NaN
# 1               -1.0           1.0          NaN  ...         -1.0
# 2                NaN           1.0          NaN  ...          NaN
# 3                NaN           NaN          NaN  ...          NaN
# 4                NaN           NaN          NaN  ...          NaN
# 5                0.0           NaN          NaN  ...          NaN
# 6                0.0           NaN          NaN  ...          NaN
# 7                NaN           NaN          NaN  ...          NaN
# 8                NaN           NaN          NaN  ...          NaN
# 9                NaN           1.0          NaN  ...          NaN
# 10               NaN           1.0          NaN  ...          NaN
# 11               1.0           NaN          NaN  ...          1.0
# 12               1.0           NaN          NaN  ...          1.0
# 13               NaN           0.0          NaN  ...          NaN
# 14               NaN           0.0          NaN  ...          NaN
# 15               NaN           NaN          NaN  ...          0.0
# 16               NaN           1.0          NaN  ...          NaN
# 17               NaN           1.0          NaN  ...          NaN
# 18               NaN           1.0          NaN  ...          NaN
# 19               NaN           1.0          NaN  ...          NaN
# 20               NaN          -1.0          NaN  ...          NaN
# 21               NaN           1.0          NaN  ...          NaN
# 22               NaN           1.0          NaN  ...          NaN
# 23               NaN           1.0          NaN  ...          NaN
# 24               NaN           1.0          NaN  ...          NaN
# 25               NaN           NaN          NaN  ...          NaN
# 26               NaN           NaN          NaN  ...          NaN
# 27              -1.0           0.0          NaN  ...          NaN
# 28              -1.0           0.0          NaN  ...          NaN
# 29               NaN           NaN          NaN  ...          NaN
# ...              ...           ...          ...  ...          ...
# 178930           1.0           1.0          0.0  ...          0.0
# 178931           1.0           1.0          0.0  ...          0.0
# 178932           0.0           0.0          0.0  ...          0.0
# 178933           0.0           1.0          0.0  ...          1.0
# 178934           0.0           1.0          0.0  ...          1.0
# 178935           0.0           0.0          0.0  ...          0.0
# 178936           1.0           1.0          0.0  ...          1.0
# 178937           0.0           1.0          0.0  ...          0.0
# 178938           1.0           0.0          0.0  ...          0.0
# 178939           0.0           0.0          0.0  ...          0.0
# 178940           0.0           0.0          0.0  ...          0.0
# 178941           1.0           1.0          0.0  ...          1.0
# 178942           0.0           1.0          0.0  ...          0.0
# 178943           0.0           0.0          0.0  ...          0.0
# 178944           0.0           1.0          0.0  ...          1.0
# 178945           0.0           0.0          0.0  ...          0.0
# 178946           0.0           0.0          0.0  ...          0.0
# 178947           0.0           0.0          0.0  ...          0.0
# 178948           1.0           1.0          0.0  ...          0.0
# 178949           0.0           0.0          0.0  ...          0.0
# 178950           0.0           0.0          0.0  ...          0.0
# 178951           1.0           1.0          0.0  ...          0.0
# 178952           0.0           1.0          0.0  ...          0.0
# 178953           0.0           1.0          0.0  ...          1.0
# 178954           0.0           1.0          0.0  ...          1.0
# 178955           0.0           0.0          0.0  ...          0.0
# 178956           0.0           0.0          0.0  ...          0.0
# 178957           1.0           1.0          0.0  ...          0.0
# 178958           0.0           0.0          0.0  ...          0.0
# 178959           0.0           1.0          0.0  ...          1.0
#
#         Pneumothorax  Pleural Effusion  Pleural Other  Fracture  \
# 0                0.0               NaN            NaN       NaN
# 1                NaN              -1.0            NaN       1.0
# 2                NaN               NaN            NaN       1.0
# 3                0.0               NaN            NaN       NaN
# 4                NaN               0.0            NaN       NaN
# 5                NaN               0.0            NaN       NaN
# 6                NaN               0.0            NaN       NaN
# 7                1.0               NaN            NaN       NaN
# 8                NaN               0.0            NaN       NaN
# 9                NaN               1.0            NaN       NaN
# 10               0.0               1.0            NaN       NaN
# 11               NaN               NaN            NaN       NaN
# 12               NaN               NaN            NaN       NaN
# 13               NaN               0.0            NaN       NaN
# 14               NaN               0.0            NaN       NaN
# 15               0.0               0.0            NaN       NaN
# 16              -1.0              -1.0            NaN       NaN
# 17               NaN               NaN            NaN       NaN
# 18               NaN               1.0            NaN       NaN
# 19               NaN               1.0            NaN       NaN
# 20               NaN               1.0            NaN       NaN
# 21               NaN               1.0            NaN       NaN
# 22               NaN               NaN            NaN       NaN
# 23               1.0               NaN            NaN       NaN
# 24               1.0               NaN            NaN       NaN
# 25               0.0               1.0            NaN       NaN
# 26               0.0               1.0            NaN       NaN
# 27               NaN               0.0            NaN       NaN
# 28               NaN               0.0            NaN       NaN
# 29               NaN               0.0            NaN       NaN
# ...              ...               ...            ...       ...
# 178930           1.0               1.0            0.0       0.0
# 178931           0.0               0.0            0.0       0.0
# 178932           0.0               0.0            0.0       0.0
# 178933           0.0               0.0            0.0       0.0
# 178934           0.0               1.0            0.0       0.0
# 178935           0.0               0.0            0.0       0.0
# 178936           0.0               0.0            0.0       0.0
# 178937           0.0               1.0            0.0       0.0
# 178938           0.0               0.0            0.0       0.0
# 178939           0.0               1.0            0.0       0.0
# 178940           0.0               0.0            0.0       0.0
# 178941           0.0               1.0            0.0       0.0
# 178942           0.0               0.0            0.0       0.0
# 178943           0.0               0.0            0.0       0.0
# 178944           0.0               1.0            0.0       0.0
# 178945           0.0               0.0            0.0       0.0
# 178946           0.0               0.0            0.0       0.0
# 178947           0.0               0.0            0.0       0.0
# 178948           0.0               0.0            0.0       0.0
# 178949           0.0               0.0            0.0       0.0
# 178950           0.0               0.0            0.0       0.0
# 178951           0.0               0.0            0.0       0.0
# 178952           0.0               0.0            0.0       0.0
# 178953           0.0               0.0            0.0       0.0
# 178954           0.0               0.0            0.0       0.0
# 178955           0.0               0.0            0.0       0.0
# 178956           0.0               0.0            0.0       0.0
# 178957           0.0               0.0            0.0       0.0
# 178958           0.0               0.0            0.0       0.0
# 178959           0.0               1.0            0.0       0.0
#
#         Support Devices  train_valid       patient    study  \
# 0                   1.0        False  patient00001   study1
# 1                   NaN        False  patient00002   study2
# 2                   NaN        False  patient00002   study1
# 3                   NaN        False  patient00003   study1
# 4                   NaN        False  patient00004   study1
# 5                   1.0        False  patient00005   study1
# 6                   1.0        False  patient00005   study1
# 7                   NaN        False  patient00005   study2
# 8                   NaN        False  patient00006   study1
# 9                   1.0        False  patient00008   study1
# 10                  1.0        False  patient00008   study2
# 11                  NaN        False  patient00009   study1
# 12                  NaN        False  patient00009   study1
# 13                  NaN        False  patient00010   study1
# 14                  NaN        False  patient00010   study1
# 15                  NaN        False  patient00011  study13
# 16                  1.0        False  patient00011   study1
# 17                  1.0        False  patient00011   study7
# 18                  1.0        False  patient00011   study2
# 19                  1.0        False  patient00011  study10
# 20                  1.0        False  patient00011   study9
# 21                  1.0        False  patient00011  study11
# 22                  1.0        False  patient00011   study8
# 23                  1.0        False  patient00011   study3
# 24                  NaN        False  patient00011   study6
# 25                  1.0        False  patient00012   study3
# 26                  1.0        False  patient00012   study3
# 27                  1.0        False  patient00012   study2
# 28                  1.0        False  patient00012   study2
# 29                  1.0        False  patient00012   study1
# ...                 ...          ...           ...      ...
# 178930              1.0         True  patient64711   study1
# 178931              1.0         True  patient64712   study1
# 178932              1.0         True  patient64713   study1
# 178933              1.0         True  patient64714   study1
# 178934              0.0         True  patient64715   study1
# 178935              0.0         True  patient64716   study1
# 178936              1.0         True  patient64717   study1
# 178937              0.0         True  patient64718   study1
# 178938              1.0         True  patient64719   study1
# 178939              1.0         True  patient64720   study1
# 178940              0.0         True  patient64721   study1
# 178941              1.0         True  patient64722   study1
# 178942              1.0         True  patient64723   study1
# 178943              1.0         True  patient64724   study1
# 178944              1.0         True  patient64725   study1
# 178945              1.0         True  patient64726   study1
# 178946              0.0         True  patient64727   study1
# 178947              1.0         True  patient64728   study1
# 178948              0.0         True  patient64729   study1
# 178949              1.0         True  patient64730   study1
# 178950              1.0         True  patient64731   study1
# 178951              0.0         True  patient64732   study1
# 178952              0.0         True  patient64733   study1
# 178953              0.0         True  patient64734   study1
# 178954              0.0         True  patient64735   study1
# 178955              1.0         True  patient64736   study1
# 178956              1.0         True  patient64737   study1
# 178957              1.0         True  patient64738   study1
# 178958              0.0         True  patient64739   study1
# 178959              0.0         True  patient64740   study1
#
#                                            feature_string
# 0
# 1
# 2
# 3                                                 Edema_p
# 4                      Consolidation_n;Pleural Effusion_n
# 5       Cardiomegaly_n;Consolidation_n;Pleural Effusion_n
# 6       Cardiomegaly_n;Consolidation_n;Pleural Effusion_n
# 7
# 8                                      Pleural Effusion_n
# 9                                      Pleural Effusion_p
# 10                                     Pleural Effusion_p
# 11                   Atelectasis_p;Cardiomegaly_p;Edema_n
# 12                   Atelectasis_p;Cardiomegaly_p;Edema_n
# 13                                     Pleural Effusion_n
# 14                                     Pleural Effusion_n
# 15       Atelectasis_n;Consolidation_n;Pleural Effusion_n
# 16
# 17                                                Edema_n
# 18                     Consolidation_p;Pleural Effusion_p
# 19                             Edema_p;Pleural Effusion_p
# 20                                     Pleural Effusion_p
# 21                             Edema_p;Pleural Effusion_p
# 22                                                Edema_n
# 23
# 24
# 25                     Consolidation_n;Pleural Effusion_p
# 26                     Consolidation_n;Pleural Effusion_p
# 27                     Consolidation_n;Pleural Effusion_n
# 28                     Consolidation_n;Pleural Effusion_n
# 29                                     Pleural Effusion_n
# ...                                                   ...
# 178930  Atelectasis_n;Cardiomegaly_p;Consolidation_n;E...
# 178931  Atelectasis_n;Cardiomegaly_p;Consolidation_n;E...
# 178932  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178933  Atelectasis_p;Cardiomegaly_n;Consolidation_n;E...
# 178934  Atelectasis_p;Cardiomegaly_n;Consolidation_p;E...
# 178935  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178936  Atelectasis_p;Cardiomegaly_p;Consolidation_p;E...
# 178937  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178938  Atelectasis_n;Cardiomegaly_p;Consolidation_n;E...
# 178939  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178940  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178941  Atelectasis_p;Cardiomegaly_p;Consolidation_p;E...
# 178942  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178943  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178944  Atelectasis_p;Cardiomegaly_n;Consolidation_n;E...
# 178945  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178946  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178947  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178948  Atelectasis_n;Cardiomegaly_p;Consolidation_n;E...
# 178949  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178950  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178951  Atelectasis_n;Cardiomegaly_p;Consolidation_n;E...
# 178952  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178953  Atelectasis_p;Cardiomegaly_n;Consolidation_n;E...
# 178954  Atelectasis_p;Cardiomegaly_n;Consolidation_n;E...
# 178955  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178956  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178957  Atelectasis_n;Cardiomegaly_p;Consolidation_n;E...
# 178958  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178959  Atelectasis_p;Cardiomegaly_n;Consolidation_n;E...
#
# [178960 rows x 23 columns]

# %% [markdown]
# ### Set up a small sample for fast iteration

# %%
def get_sample_df(sample_perc = 0.05):
    np.random.seed(99)
    
    train_only_df = full_df[~full_df.train_valid]
    valid_only_df = full_df[full_df.train_valid]
    unique_patients = train_only_df.patient.unique()
    mask = np.random.rand(len(unique_patients)) < sample_perc
    sample_patients = unique_patients[mask]

    sample_df = train_only_df[full_train_df.patient.isin(sample_patients)]
    return pd.concat([sample_df,valid_only_df])

# %% [markdown]
# ### Set up data set using Fastai datablock

# %%
def get_src(df = full_df):
    return (ImageList
        .from_df(df, data_path, 'Path')
        .split_from_df('train_valid')
        .label_from_df('feature_string',label_delim=';')
       )

# %%
def get_data(size, src, bs=32):
    return (src.transform(get_transforms(do_flip=False), size=size, padding_mode='zeros')
        .databunch(bs=bs).normalize(imagenet_stats))

# %% [markdown]
# ## Create a function to evaluate performance of all features

# %%
def get_preds_per_study():
    valid_preds=learn.get_preds(ds_type=DatasetType.Valid)[0]
   
    for i, c in enumerate(learn.data.classes):
        full_valid_df[c] = valid_preds[:,i]
    
    return full_valid_df.groupby(['patient','study'])[learn.data.classes].max().reset_index()

# %%
def get_df_onehot(df):
    for c in u_targets:
        df[c] = [None]*len(df)
    for idx,r in df.iterrows():
        for c in chexpert_targets:
            if r[c] == -1:
                # df.loc[idx,c] = None
                df.loc[idx,c+'_p'] = 0
                df.loc[idx,c+'_n'] = 0
            elif r[c] == 1:
                # df.loc[idx,c] = None
                df.loc[idx,c+'_p'] = 1
                df.loc[idx,c+'_n'] = 0
            elif r[c] == 0:
                # df.loc[idx,c] = None
                df.loc[idx,c+'_p'] = 0
                df.loc[idx,c+'_n'] = 1
            else:
                # df.loc[idx,c] = None
                df.loc[idx,c+'_p'] = 0
                df.loc[idx,c+'_n'] = 0
    return df

# %%
def validation_eval(learn):
    # unlike using u_1 and u_0, we need extra classes for binary auc_roc_score
    # we will using similiar strategy as 'one_hot_encoding'
    acts = get_df_onehot(full_valid_df)
    
    # model_classes_pred = [x for x in learn.data.classes if x in chexpert_targets]
    acts = full_valid_df.groupby(['patient','study'])[learn.data.classes].max().values

    valid_preds=learn.get_preds(ds_type=DatasetType.Valid)
    preds = valid_preds[0]
    preds_df = full_valid_df.copy()

    for i, c in enumerate(learn.data.classes):
        preds_df[c] = preds[:,i]

    preds = preds_df.groupby(['patient','study'])[learn.data.classes].max().values
    
    auc_scores = {}
    
    for i in range(len(learn.data.classes)):
        # handel only one class case
        try:
            score = roc_auc_score(acts[:,i],preds[:,i])
        except ValueError:
            n_acts = acts[:,i]
            n_acts = np.append(n_acts,0)
            n_acts = np.append(n_acts,1)
            n_preds = preds[:,i]
            n_preds = np.append(n_preds,0)
            n_preds = np.append(n_preds,1)
            print(n_acts)
            score = roc_auc_score(n_acts,n_preds)
        auc_scores[learn.data.classes[i]] = score
    print(auc_scores)

#     #average results reported in the associated paper
#     chexpert_auc_scores = {'Atelectasis':      0.858,
#                            'Cardiomegaly':     0.854,
#                            'Consolidation':    0.939,
#                            'Edema':            0.941,
#                            'Pleural Effusion': 0.936}

#     max_feat_len = max(map(len, chexpert_targets))

#     avg_chexpert_auc = sum(list(chexpert_auc_scores.values()))/len(chexpert_auc_scores.values())
    avg_auc = sum(list(auc_scores.values()))/len(auc_scores.values())

    [print(f'auc: {auc_scores[k]:.3}\t') for k in u_multi_targets]

    print(f'\nAverage auc: {avg_auc:.3} \t')
    
    return avg_auc

# %% [markdown]
# ### Create callbacks to evaluate and save learner

# %%
class CheXpertEvalCallback(LearnerCallback):
    def __init__(self, learn):
        super().__init__(learn)
        self.skip = False
        self.avg_auc = 0
    def on_epoch_end(self,**kwargs):
        if self.skip: return
        self.avg_auc = validation_eval(self.learn)

# %%
class SaveCallback(LearnerCallback):
    _order = 99
    def __init__(self, learn):
        super().__init__(learn)
        self.epoch = 0
        self.skip = False
    def on_epoch_end(self, **kwargs):
        self.epoch += 1
        if self.skip: return
        learn.save(f'{datetime.datetime.now():%Y-%m-%d %H:%M} AUC:{self.che_xpert_eval_callback.avg_auc:.3}')

# %%
cbfs = [CheXpertEvalCallback, SaveCallback]

# %% [markdown]
# ### Alter LR_Finder to remove my callbacks before running

# %%
def lr_find_no_cbs(learn):
    learn.callback_fns = [cbf for cbf in learn.callback_fns if cbf not in cbfs]
    lr_find(learn)
    learn.recorder.plot(suggestion=True)
    learn.callback_fns += cbfs

# %% [markdown]
# ### Train on full set with image size 224

# %%
img_size = 224
data = get_data(img_size, get_src(full_df))
learn = cnn_learner(data, densenet121, callback_fns=cbfs)

# %%
lr_find_no_cbs(learn)

# %%
lr=1e-2
learn.fit_one_cycle(1,slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.286900</td>
#       <td>1.247276</td>
#       <td>24:43</td>
#     </tr>
#   </tbody>
# </table>

# %%
# learn = load_learner(Path('/media/trevor/main-storag/master_classes/big_data_health/BDH_project')/'models','u_ignore'+'.pkl')

# %%
# self trained result
full_preds = learn.get_preds(data)

# we let self_trained_threshold = 0.5 in this testing case
# latter try to use Average Auc
SELF_TRAINED_THRESHOLD = 0.5

preds_prob = full_preds[0]
preds_label = full_preds[1]

# %%
preds_df = full_df.copy().reset_index(drop=True)

# %%
learn.data.classes
# Out:
# ['Atelectasis_n',
#  'Atelectasis_p',
#  'Cardiomegaly_n',
#  'Cardiomegaly_p',
#  'Consolidation_n',
#  'Consolidation_p',
#  'Edema_n',
#  'Edema_p',
#  'Pleural Effusion_n',
#  'Pleural Effusion_p']

# %%
for i, c in enumerate(chexpert_targets):
    for l_i in range(0,len(preds_df[c])):
        if preds_df.loc[l_i,c] == -1:
            n = preds_prob[l_i,2*i]
            p = preds_prob[l_i,2*i+1]
            if n > p:
                preds_df.loc[l_i,c] = 0
            else:
                preds_df.loc[l_i,c] = 1

# %%
preds_df
# Out:
#                                                      Path     Sex  Age  \
# 0       CheXpert-v1.0-small/train/patient00001/study1/...  Female   68
# 1       CheXpert-v1.0-small/train/patient00002/study2/...  Female   87
# 2       CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 3       CheXpert-v1.0-small/train/patient00003/study1/...    Male   41
# 4       CheXpert-v1.0-small/train/patient00004/study1/...  Female   20
# 5       CheXpert-v1.0-small/train/patient00005/study1/...    Male   33
# 6       CheXpert-v1.0-small/train/patient00005/study1/...    Male   33
# 7       CheXpert-v1.0-small/train/patient00005/study2/...    Male   33
# 8       CheXpert-v1.0-small/train/patient00006/study1/...  Female   42
# 9       CheXpert-v1.0-small/train/patient00008/study1/...    Male   81
# 10      CheXpert-v1.0-small/train/patient00008/study2/...    Male   81
# 11      CheXpert-v1.0-small/train/patient00009/study1/...    Male   76
# 12      CheXpert-v1.0-small/train/patient00009/study1/...    Male   76
# 13      CheXpert-v1.0-small/train/patient00010/study1/...  Female   50
# 14      CheXpert-v1.0-small/train/patient00010/study1/...  Female   50
# 15      CheXpert-v1.0-small/train/patient00011/study13...  Female   22
# 16      CheXpert-v1.0-small/train/patient00011/study1/...  Female   19
# 17      CheXpert-v1.0-small/train/patient00011/study7/...  Female   19
# 18      CheXpert-v1.0-small/train/patient00011/study2/...  Female   19
# 19      CheXpert-v1.0-small/train/patient00011/study10...  Female   19
# 20      CheXpert-v1.0-small/train/patient00011/study9/...  Female   19
# 21      CheXpert-v1.0-small/train/patient00011/study11...  Female   19
# 22      CheXpert-v1.0-small/train/patient00011/study8/...  Female   19
# 23      CheXpert-v1.0-small/train/patient00011/study3/...  Female   19
# 24      CheXpert-v1.0-small/train/patient00011/study6/...  Female   19
# 25      CheXpert-v1.0-small/train/patient00012/study3/...  Female   61
# 26      CheXpert-v1.0-small/train/patient00012/study3/...  Female   61
# 27      CheXpert-v1.0-small/train/patient00012/study2/...  Female   55
# 28      CheXpert-v1.0-small/train/patient00012/study2/...  Female   55
# 29      CheXpert-v1.0-small/train/patient00012/study1/...  Female   55
# ...                                                   ...     ...  ...
# 178930  CheXpert-v1.0-small/valid/patient64711/study1/...  Female   80
# 178931  CheXpert-v1.0-small/valid/patient64712/study1/...  Female   75
# 178932  CheXpert-v1.0-small/valid/patient64713/study1/...  Female   76
# 178933  CheXpert-v1.0-small/valid/patient64714/study1/...    Male   63
# 178934  CheXpert-v1.0-small/valid/patient64715/study1/...    Male   81
# 178935  CheXpert-v1.0-small/valid/patient64716/study1/...  Female   68
# 178936  CheXpert-v1.0-small/valid/patient64717/study1/...    Male   90
# 178937  CheXpert-v1.0-small/valid/patient64718/study1/...    Male   83
# 178938  CheXpert-v1.0-small/valid/patient64719/study1/...    Male   68
# 178939  CheXpert-v1.0-small/valid/patient64720/study1/...  Female   77
# 178940  CheXpert-v1.0-small/valid/patient64721/study1/...    Male   67
# 178941  CheXpert-v1.0-small/valid/patient64722/study1/...  Female   81
# 178942  CheXpert-v1.0-small/valid/patient64723/study1/...    Male   77
# 178943  CheXpert-v1.0-small/valid/patient64724/study1/...  Female   54
# 178944  CheXpert-v1.0-small/valid/patient64725/study1/...    Male   75
# 178945  CheXpert-v1.0-small/valid/patient64726/study1/...    Male   60
# 178946  CheXpert-v1.0-small/valid/patient64727/study1/...  Female   59
# 178947  CheXpert-v1.0-small/valid/patient64728/study1/...    Male   76
# 178948  CheXpert-v1.0-small/valid/patient64729/study1/...    Male   72
# 178949  CheXpert-v1.0-small/valid/patient64730/study1/...  Female   36
# 178950  CheXpert-v1.0-small/valid/patient64731/study1/...    Male   60
# 178951  CheXpert-v1.0-small/valid/patient64732/study1/...  Female   49
# 178952  CheXpert-v1.0-small/valid/patient64733/study1/...    Male   87
# 178953  CheXpert-v1.0-small/valid/patient64734/study1/...    Male   45
# 178954  CheXpert-v1.0-small/valid/patient64735/study1/...  Female   63
# 178955  CheXpert-v1.0-small/valid/patient64736/study1/...  Female   57
# 178956  CheXpert-v1.0-small/valid/patient64737/study1/...    Male   65
# 178957  CheXpert-v1.0-small/valid/patient64738/study1/...    Male   71
# 178958  CheXpert-v1.0-small/valid/patient64739/study1/...  Female   45
# 178959  CheXpert-v1.0-small/valid/patient64740/study1/...    Male   90
#
#        Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  \
# 0              Frontal    AP         1.0                         NaN
# 1              Frontal    AP         NaN                         NaN
# 2              Frontal    AP         NaN                         NaN
# 3              Frontal    AP         NaN                         NaN
# 4              Frontal    PA         1.0                         0.0
# 5              Frontal    PA         1.0                         NaN
# 6              Lateral   NaN         1.0                         NaN
# 7              Frontal    AP         NaN                         NaN
# 8              Frontal    AP         1.0                         0.0
# 9              Frontal    AP         NaN                         NaN
# 10             Frontal    AP         NaN                         NaN
# 11             Frontal    PA         NaN                         NaN
# 12             Lateral   NaN         NaN                         NaN
# 13             Frontal    PA         1.0                         0.0
# 14             Lateral   NaN         1.0                         0.0
# 15             Frontal    PA         NaN                         0.0
# 16             Frontal    AP         NaN                         NaN
# 17             Frontal    AP         NaN                         NaN
# 18             Frontal    AP         NaN                         NaN
# 19             Frontal    AP         NaN                         NaN
# 20             Frontal    AP         NaN                         1.0
# 21             Frontal    AP         NaN                         NaN
# 22             Frontal    AP         NaN                         NaN
# 23             Frontal    AP         NaN                         NaN
# 24             Frontal    AP         NaN                         NaN
# 25             Frontal    PA         NaN                         0.0
# 26             Lateral   NaN         NaN                         0.0
# 27             Frontal    PA         NaN                        -1.0
# 28             Lateral   NaN         NaN                        -1.0
# 29             Frontal    PA         NaN                         0.0
# ...                ...   ...         ...                         ...
# 178930         Frontal    AP         0.0                         1.0
# 178931         Frontal    AP         0.0                         1.0
# 178932         Frontal    AP         0.0                         0.0
# 178933         Frontal    AP         0.0                         1.0
# 178934         Frontal    AP         0.0                         0.0
# 178935         Frontal    AP         1.0                         0.0
# 178936         Frontal    AP         0.0                         1.0
# 178937         Frontal    AP         0.0                         1.0
# 178938         Frontal    AP         0.0                         1.0
# 178939         Frontal    AP         0.0                         0.0
# 178940         Frontal    AP         1.0                         0.0
# 178941         Frontal    AP         0.0                         1.0
# 178942         Frontal    AP         0.0                         1.0
# 178943         Frontal    AP         0.0                         0.0
# 178944         Frontal    AP         0.0                         0.0
# 178945         Frontal    AP         0.0                         1.0
# 178946         Frontal    AP         1.0                         0.0
# 178947         Frontal    AP         0.0                         0.0
# 178948         Frontal    AP         0.0                         1.0
# 178949         Frontal    AP         0.0                         0.0
# 178950         Frontal    AP         0.0                         0.0
# 178951         Frontal    AP         0.0                         1.0
# 178952         Frontal    AP         0.0                         1.0
# 178953         Frontal    AP         0.0                         1.0
# 178954         Frontal    AP         0.0                         0.0
# 178955         Frontal    AP         0.0                         0.0
# 178956         Frontal    AP         0.0                         0.0
# 178957         Frontal    AP         0.0                         1.0
# 178958         Frontal    AP         0.0                         1.0
# 178959         Frontal    AP         0.0                         1.0
#
#         Cardiomegaly  Lung Opacity  Lung Lesion  ...  Atelectasis  \
# 0                NaN           NaN          NaN  ...          NaN
# 1                1.0           1.0          NaN  ...          1.0
# 2                NaN           1.0          NaN  ...          NaN
# 3                NaN           NaN          NaN  ...          NaN
# 4                NaN           NaN          NaN  ...          NaN
# 5                0.0           NaN          NaN  ...          NaN
# 6                0.0           NaN          NaN  ...          NaN
# 7                NaN           NaN          NaN  ...          NaN
# 8                NaN           NaN          NaN  ...          NaN
# 9                NaN           1.0          NaN  ...          NaN
# 10               NaN           1.0          NaN  ...          NaN
# 11               1.0           NaN          NaN  ...          1.0
# 12               1.0           NaN          NaN  ...          1.0
# 13               NaN           0.0          NaN  ...          NaN
# 14               NaN           0.0          NaN  ...          NaN
# 15               NaN           NaN          NaN  ...          0.0
# 16               NaN           1.0          NaN  ...          NaN
# 17               NaN           1.0          NaN  ...          NaN
# 18               NaN           1.0          NaN  ...          NaN
# 19               NaN           1.0          NaN  ...          NaN
# 20               NaN          -1.0          NaN  ...          NaN
# 21               NaN           1.0          NaN  ...          NaN
# 22               NaN           1.0          NaN  ...          NaN
# 23               NaN           1.0          NaN  ...          NaN
# 24               NaN           1.0          NaN  ...          NaN
# 25               NaN           NaN          NaN  ...          NaN
# 26               NaN           NaN          NaN  ...          NaN
# 27               0.0           0.0          NaN  ...          NaN
# 28               0.0           0.0          NaN  ...          NaN
# 29               NaN           NaN          NaN  ...          NaN
# ...              ...           ...          ...  ...          ...
# 178930           1.0           1.0          0.0  ...          0.0
# 178931           1.0           1.0          0.0  ...          0.0
# 178932           0.0           0.0          0.0  ...          0.0
# 178933           0.0           1.0          0.0  ...          1.0
# 178934           0.0           1.0          0.0  ...          1.0
# 178935           0.0           0.0          0.0  ...          0.0
# 178936           1.0           1.0          0.0  ...          1.0
# 178937           0.0           1.0          0.0  ...          0.0
# 178938           1.0           0.0          0.0  ...          0.0
# 178939           0.0           0.0          0.0  ...          0.0
# 178940           0.0           0.0          0.0  ...          0.0
# 178941           1.0           1.0          0.0  ...          1.0
# 178942           0.0           1.0          0.0  ...          0.0
# 178943           0.0           0.0          0.0  ...          0.0
# 178944           0.0           1.0          0.0  ...          1.0
# 178945           0.0           0.0          0.0  ...          0.0
# 178946           0.0           0.0          0.0  ...          0.0
# 178947           0.0           0.0          0.0  ...          0.0
# 178948           1.0           1.0          0.0  ...          0.0
# 178949           0.0           0.0          0.0  ...          0.0
# 178950           0.0           0.0          0.0  ...          0.0
# 178951           1.0           1.0          0.0  ...          0.0
# 178952           0.0           1.0          0.0  ...          0.0
# 178953           0.0           1.0          0.0  ...          1.0
# 178954           0.0           1.0          0.0  ...          1.0
# 178955           0.0           0.0          0.0  ...          0.0
# 178956           0.0           0.0          0.0  ...          0.0
# 178957           1.0           1.0          0.0  ...          0.0
# 178958           0.0           0.0          0.0  ...          0.0
# 178959           0.0           1.0          0.0  ...          1.0
#
#         Pneumothorax  Pleural Effusion  Pleural Other  Fracture  \
# 0                0.0               NaN            NaN       NaN
# 1                NaN               0.0            NaN       1.0
# 2                NaN               NaN            NaN       1.0
# 3                0.0               NaN            NaN       NaN
# 4                NaN               0.0            NaN       NaN
# 5                NaN               0.0            NaN       NaN
# 6                NaN               0.0            NaN       NaN
# 7                1.0               NaN            NaN       NaN
# 8                NaN               0.0            NaN       NaN
# 9                NaN               1.0            NaN       NaN
# 10               0.0               1.0            NaN       NaN
# 11               NaN               NaN            NaN       NaN
# 12               NaN               NaN            NaN       NaN
# 13               NaN               0.0            NaN       NaN
# 14               NaN               0.0            NaN       NaN
# 15               0.0               0.0            NaN       NaN
# 16              -1.0               0.0            NaN       NaN
# 17               NaN               NaN            NaN       NaN
# 18               NaN               1.0            NaN       NaN
# 19               NaN               1.0            NaN       NaN
# 20               NaN               1.0            NaN       NaN
# 21               NaN               1.0            NaN       NaN
# 22               NaN               NaN            NaN       NaN
# 23               1.0               NaN            NaN       NaN
# 24               1.0               NaN            NaN       NaN
# 25               0.0               1.0            NaN       NaN
# 26               0.0               1.0            NaN       NaN
# 27               NaN               0.0            NaN       NaN
# 28               NaN               0.0            NaN       NaN
# 29               NaN               0.0            NaN       NaN
# ...              ...               ...            ...       ...
# 178930           1.0               1.0            0.0       0.0
# 178931           0.0               0.0            0.0       0.0
# 178932           0.0               0.0            0.0       0.0
# 178933           0.0               0.0            0.0       0.0
# 178934           0.0               1.0            0.0       0.0
# 178935           0.0               0.0            0.0       0.0
# 178936           0.0               0.0            0.0       0.0
# 178937           0.0               1.0            0.0       0.0
# 178938           0.0               0.0            0.0       0.0
# 178939           0.0               1.0            0.0       0.0
# 178940           0.0               0.0            0.0       0.0
# 178941           0.0               1.0            0.0       0.0
# 178942           0.0               0.0            0.0       0.0
# 178943           0.0               0.0            0.0       0.0
# 178944           0.0               1.0            0.0       0.0
# 178945           0.0               0.0            0.0       0.0
# 178946           0.0               0.0            0.0       0.0
# 178947           0.0               0.0            0.0       0.0
# 178948           0.0               0.0            0.0       0.0
# 178949           0.0               0.0            0.0       0.0
# 178950           0.0               0.0            0.0       0.0
# 178951           0.0               0.0            0.0       0.0
# 178952           0.0               0.0            0.0       0.0
# 178953           0.0               0.0            0.0       0.0
# 178954           0.0               0.0            0.0       0.0
# 178955           0.0               0.0            0.0       0.0
# 178956           0.0               0.0            0.0       0.0
# 178957           0.0               0.0            0.0       0.0
# 178958           0.0               0.0            0.0       0.0
# 178959           0.0               1.0            0.0       0.0
#
#         Support Devices  train_valid       patient    study  \
# 0                   1.0        False  patient00001   study1
# 1                   NaN        False  patient00002   study2
# 2                   NaN        False  patient00002   study1
# 3                   NaN        False  patient00003   study1
# 4                   NaN        False  patient00004   study1
# 5                   1.0        False  patient00005   study1
# 6                   1.0        False  patient00005   study1
# 7                   NaN        False  patient00005   study2
# 8                   NaN        False  patient00006   study1
# 9                   1.0        False  patient00008   study1
# 10                  1.0        False  patient00008   study2
# 11                  NaN        False  patient00009   study1
# 12                  NaN        False  patient00009   study1
# 13                  NaN        False  patient00010   study1
# 14                  NaN        False  patient00010   study1
# 15                  NaN        False  patient00011  study13
# 16                  1.0        False  patient00011   study1
# 17                  1.0        False  patient00011   study7
# 18                  1.0        False  patient00011   study2
# 19                  1.0        False  patient00011  study10
# 20                  1.0        False  patient00011   study9
# 21                  1.0        False  patient00011  study11
# 22                  1.0        False  patient00011   study8
# 23                  1.0        False  patient00011   study3
# 24                  NaN        False  patient00011   study6
# 25                  1.0        False  patient00012   study3
# 26                  1.0        False  patient00012   study3
# 27                  1.0        False  patient00012   study2
# 28                  1.0        False  patient00012   study2
# 29                  1.0        False  patient00012   study1
# ...                 ...          ...           ...      ...
# 178930              1.0         True  patient64711   study1
# 178931              1.0         True  patient64712   study1
# 178932              1.0         True  patient64713   study1
# 178933              1.0         True  patient64714   study1
# 178934              0.0         True  patient64715   study1
# 178935              0.0         True  patient64716   study1
# 178936              1.0         True  patient64717   study1
# 178937              0.0         True  patient64718   study1
# 178938              1.0         True  patient64719   study1
# 178939              1.0         True  patient64720   study1
# 178940              0.0         True  patient64721   study1
# 178941              1.0         True  patient64722   study1
# 178942              1.0         True  patient64723   study1
# 178943              1.0         True  patient64724   study1
# 178944              1.0         True  patient64725   study1
# 178945              1.0         True  patient64726   study1
# 178946              0.0         True  patient64727   study1
# 178947              1.0         True  patient64728   study1
# 178948              0.0         True  patient64729   study1
# 178949              1.0         True  patient64730   study1
# 178950              1.0         True  patient64731   study1
# 178951              0.0         True  patient64732   study1
# 178952              0.0         True  patient64733   study1
# 178953              0.0         True  patient64734   study1
# 178954              0.0         True  patient64735   study1
# 178955              1.0         True  patient64736   study1
# 178956              1.0         True  patient64737   study1
# 178957              1.0         True  patient64738   study1
# 178958              0.0         True  patient64739   study1
# 178959              0.0         True  patient64740   study1
#
#                                            feature_string
# 0
# 1
# 2
# 3                                                 Edema_p
# 4                      Consolidation_n;Pleural Effusion_n
# 5       Cardiomegaly_n;Consolidation_n;Pleural Effusion_n
# 6       Cardiomegaly_n;Consolidation_n;Pleural Effusion_n
# 7
# 8                                      Pleural Effusion_n
# 9                                      Pleural Effusion_p
# 10                                     Pleural Effusion_p
# 11                   Atelectasis_p;Cardiomegaly_p;Edema_n
# 12                   Atelectasis_p;Cardiomegaly_p;Edema_n
# 13                                     Pleural Effusion_n
# 14                                     Pleural Effusion_n
# 15       Atelectasis_n;Consolidation_n;Pleural Effusion_n
# 16
# 17                                                Edema_n
# 18                     Consolidation_p;Pleural Effusion_p
# 19                             Edema_p;Pleural Effusion_p
# 20                                     Pleural Effusion_p
# 21                             Edema_p;Pleural Effusion_p
# 22                                                Edema_n
# 23
# 24
# 25                     Consolidation_n;Pleural Effusion_p
# 26                     Consolidation_n;Pleural Effusion_p
# 27                     Consolidation_n;Pleural Effusion_n
# 28                     Consolidation_n;Pleural Effusion_n
# 29                                     Pleural Effusion_n
# ...                                                   ...
# 178930  Atelectasis_n;Cardiomegaly_p;Consolidation_n;E...
# 178931  Atelectasis_n;Cardiomegaly_p;Consolidation_n;E...
# 178932  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178933  Atelectasis_p;Cardiomegaly_n;Consolidation_n;E...
# 178934  Atelectasis_p;Cardiomegaly_n;Consolidation_p;E...
# 178935  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178936  Atelectasis_p;Cardiomegaly_p;Consolidation_p;E...
# 178937  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178938  Atelectasis_n;Cardiomegaly_p;Consolidation_n;E...
# 178939  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178940  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178941  Atelectasis_p;Cardiomegaly_p;Consolidation_p;E...
# 178942  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178943  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178944  Atelectasis_p;Cardiomegaly_n;Consolidation_n;E...
# 178945  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178946  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178947  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178948  Atelectasis_n;Cardiomegaly_p;Consolidation_n;E...
# 178949  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178950  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178951  Atelectasis_n;Cardiomegaly_p;Consolidation_n;E...
# 178952  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178953  Atelectasis_p;Cardiomegaly_n;Consolidation_n;E...
# 178954  Atelectasis_p;Cardiomegaly_n;Consolidation_n;E...
# 178955  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178956  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178957  Atelectasis_n;Cardiomegaly_p;Consolidation_n;E...
# 178958  Atelectasis_n;Cardiomegaly_n;Consolidation_n;E...
# 178959  Atelectasis_p;Cardiomegaly_n;Consolidation_n;E...
#
# [178960 rows x 23 columns]

# %%
preds_df['feature_string'] = preds_df.apply(feature_string,axis = 1).fillna('')

# %%
# for i, c in enumerate(learn.data.classes):
#     for l_i in range(0,len(preds_df[c])):
#         if preds_df.loc[l_i,c] == -1:
#             preds_df.loc[l_i,c] = preds_label[l_i,i].item()
data = get_data(img_size, get_src(preds_df), bs=40)
learn_2 = cnn_learner(data, densenet121, callback_fns=cbfs)
lr = 5e-5
learn_2.fit_one_cycle(1,slice(lr))
# Out:
# {'Atelectasis_n': 0.5888, 'Atelectasis_p': 0.6926933333333334, 'Cardiomegaly_n': 0.6819312528267752, 'Cardiomegaly_p': 0.6584124830393487, 'Consolidation_n': 0.8173363095238094, 'Consolidation_p': 0.6917782738095237, 'Edema_n': 0.7257383966244726, 'Edema_p': 0.8352923447860157, 'Pleural Effusion_n': 0.7494255514705883, 'Pleural Effusion_p': 0.7752757352941176}
# auc: 0.693
# auc: 0.658
# auc: 0.692
# auc: 0.835
# auc: 0.775
# auc: 0.589
# auc: 0.682
# auc: 0.817
# auc: 0.726
# auc: 0.749
#
# Average auc: 0.722

# %%
# learn_2.export(Path('/media/trevor/main-storag/master_classes/big_data_health/BDH_project')/'models'/'u_selftrained.pkl')
learn.save('/media/trevor/main-storag/master_classes/big_data_health/BDH_project/models/u_selftrained')

# %% [markdown]
# ### Train on sample set with image size 224

# %%
sample_df = get_sample_df(0.02)

# %%
img_size = 224
data = get_data(img_size, get_src(sample_df), bs=40)
learn = cnn_learner(data, densenet121, callback_fns=cbfs)

# %%
# learn.load('blah');

# %%
lr_find_no_cbs(learn)

# %%
lr = 5e-5
learn.fit_one_cycle(1,slice(lr))

# %%
predicts = learn.get_preds(data)

# %%
predicts_prob = predicts[0]
predicts_label = predicts[1]

# %%
predicts_df = sample_df.copy().reset_index(drop=True)

# %%
predicts_df

# %%
for i, c in enumerate(chexpert_targets):
    print(c)
    for l_i in range(0,len(predicts_df[c])):
        if predicts_df.loc[l_i,c] == -1:
            n = predicts_prob[l_i,2*i]
            p = predicts_prob[l_i,2*i+1]
            if n > p:
                # predicts_df.loc[l_i,'feature_string'] = predicts_df.loc[l_i,'feature_string'] + ';' + (c+'_n')
                predicts_df.loc[l_i,c] = 0
            else:
                # predicts_df.loc[l_i,'feature_string'] = predicts_df.loc[l_i,'feature_string'] + ';' + (c+'_p')
                predicts_df.loc[l_i,c] = 1

# %%
predicts_df

# %%
predicts_df['feature_string'] = predicts_df.apply(feature_string,axis = 1).fillna('')

# %%
predicts_df

# %%
data_2 = get_data(img_size, get_src(predicts_df), bs=40)
learn_2 = cnn_learner(data, densenet121, callback_fns=cbfs)

# %%
lr = 5e-5
learn_2.fit_one_cycle(1,slice(lr))

# %%
# !ls /media/trevor/main-storag/models

# %% [markdown]
# ### Export entire model

# %%
# if learn is None:
#     learn = load_learner(data_path/'models','naive_densenet.pkl')
# else:
#     full_train_df['patient'] = full_train_df.Path.str.split('/',3,True)[2]
#     learn.export(data_path/'models'/'size_{img_size}_auc_{self.avg_auc}_{datetime.datetime.now(): "%Y-%m-%d %H:%M"}.pkl')

# %% [markdown]
# ### Things to try to improve score
#
# - Building more sophisticated model structure to account for unknowns
# - Curriculum learning
# - Mixup
# - Use the labelling tool from the ChexPert paper : https://github.com/stanfordmlgroup/chexpert-labeler
